# %% [markdown]
# ### Problem Statemant:
#
#     * This Real Estate Market Analysis with Python project aims for you to preprocess, analyze, and visualize the real estate property data, thereby generating meaningful insights about property transactions and customer profiles.
#
# ### Data:
#     * The data in this Real Estate Market Analysis with Python project is divided into two main tables. The first dataset contains details about the properties, including ID, building details, sale date, etc. The second dataset comprises customer details, such as customer ID, entity, name, surname, and more.
#
# ### Workflow:
#     Part 1: Data Preprocessing
#     Part 2: Descriptive Statistics
#     Part 3: Data Analysis
#     Part 4: Data Visualization
#     part 5: Data modeling
#     Part 6: Data Interpretation

# %%
import pandas as pd

# %% [markdown]
#  ### Data Preprocessing
#            * The initial stage involves cleaning and preparing the data for real estate analysis, including handling missing values, correcting inconsistencies, and transforming data types if necessary. You must clean and preprocess the customers and property tables, ensure column names are in order and that missing values appear correctly, and apply any column data type changes you see fit.
#           *  Finally, you should combine the properties and customers tables into one unified real estate dataset using the shared customer_idcolumn. You must consolidate inconsistencies or missing values to perform the following analysis and obtain the correct results

# %%
pd.options.display.max_columns = None

# %%
customer = pd.read_csv("/home/godfather101/Documents/Python-real_estate_analysis-master/customers.csv") ## Customer.csv
customer.head()
# Out:
#    Unnamed: 0 ﻿customerid      entity     name  surname  birth_date  sex  \
# 0           0       C0110  Individual   Kareem      Liu   5/11/1968    F
# 1           1       C0010  Individual  Trystan  Oconnor  11/26/1962    M
# 2           2       C0132  Individual     Kale      Gay    4/7/1959    M
# 3           3       C0137  Individual  Russell    Gross  11/25/1959    M
# 4           4       C0174     Company  Marleez       Co         NaN  NaN
#
#   country       state     purpose  deal_satisfaction mortgage   source
# 0     USA  California        Home                  4      Yes  Website
# 1     USA  California        Home                  1       No  Website
# 2     USA  California        Home                  4      Yes   Agency
# 3     USA  California        Home                  5       No  Website
# 4    USA   California  Investment                  5       No  Website

# %%
properties = pd.read_csv("/home/godfather101/Documents/Python-real_estate_analysis-master/properties.csv") ## properties.csv
properties.head()
# Out:
#    Unnamed: 0   ﻿id  building  date_sale       type  property#     area  \
# 0           0  1030         1  11/1/2005  Apartment         30   743.09
# 1           1  1029         1  10/1/2005  Apartment         29   756.21
# 2           2  2002         2   7/1/2007  Apartment          2   587.28
# 3           3  2031         2  12/1/2007  Apartment         31  1604.75
# 4           4  1049         1  11/1/2004  Apartment         49  1375.45
#
#           price  status customerid
# 0  $246,172.68    Sold      C0028
# 1  $246,331.90    Sold      C0027
# 2  $209,280.91    Sold      C0112
# 3  $452,667.01    Sold      C0160
# 4  $467,083.31    Sold      C0014

# %%
customer.info() ## info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         162 non-null    int64
#  1   ﻿customerid        162 non-null    object
#  2   entity             162 non-null    object
#  3   name               162 non-null    object
#  4   surname            162 non-null    object
#  5   birth_date         155 non-null    object
#  6   sex                155 non-null    object
#  7   country            162 non-null    object
#  8   state              154 non-null    object
#  9   purpose            162 non-null    object
#  10  deal_satisfaction  162 non-null    int64
#  11  mortgage           162 non-null    object
#  12  source             162 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 16.6+ KB

# %%
properties.info() ## info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  267 non-null    int64
#  1   ﻿id         267 non-null    int64
#  2   building    267 non-null    int64
#  3   date_sale   267 non-null    object
#  4   type        267 non-null    object
#  5   property#   267 non-null    int64
#  6   area        267 non-null    float64
#  7   price       267 non-null    object
#  8   status      267 non-null    object
#  9   customerid  195 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 21.0+ KB

# %%
properties["customerid"].isnull().sum() ## Null Values
# Out:
# 72

# %%
### For customer dataframe fillna is good
def data_cleaning(data):
    data.drop_duplicates(inplace=True)
    for col in data.columns:
        if data[col].isnull().sum() > 0:
            if data[col].dtypes == "O":
                data[col].fillna(data[col].mode()[0],inplace=True)
            else:
                data[col].fillna(data[col].mean(),inplace=True)

# %%
data_cleaning(customer)

# %%
customer.isnull().sum() ## Missing Values
# Out:
# Unnamed: 0           0
# ﻿customerid          0
# entity               0
# name                 0
# surname              0
# birth_date           0
# sex                  0
# country              0
# state                0
# purpose              0
# deal_satisfaction    0
# mortgage             0
# source               0
# dtype: int64

# %%
properties.info() # info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  267 non-null    int64
#  1   ﻿id         267 non-null    int64
#  2   building    267 non-null    int64
#  3   date_sale   267 non-null    object
#  4   type        267 non-null    object
#  5   property#   267 non-null    int64
#  6   area        267 non-null    float64
#  7   price       267 non-null    object
#  8   status      267 non-null    object
#  9   customerid  195 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 21.0+ KB

# %%
data_cleaning(properties)

# %%
properties.isnull().sum()
# Out:
# Unnamed: 0    0
# ﻿id           0
# building      0
# date_sale     0
# type          0
# property#     0
# area          0
# price         0
# status        0
# customerid    0
# dtype: int64

# %%
properties.drop('Unnamed: 0',axis=1,inplace=True) ## drop columns
customer.drop('Unnamed: 0',axis=1,inplace=True)

# %%
properties.describe() ## describtion of data
# Out:
#                ﻿id    building   property#         area
# count   267.000000  267.000000  267.000000   267.000000
# mean   2975.142322    2.947566   27.580524   936.221311
# std    1392.197474    1.391794   15.361437   284.894858
# min    1002.000000    1.000000    1.000000   410.710000
# 25%    2015.500000    2.000000   14.500000   756.210000
# 50%    3024.000000    3.000000   28.000000   798.280000
# 75%    4031.500000    4.000000   40.000000  1121.950000
# max    5052.000000    5.000000   59.000000  1942.500000

# %%
customer.describe()
# Out:
#        deal_satisfaction
# count         162.000000
# mean            3.456790
# std             1.333276
# min             1.000000
# 25%             3.000000
# 50%             4.000000
# 75%             5.000000
# max             5.000000

# %%
properties.columns = ["id", 'building', 'date_sale', 'type', 'property', 'area', 'price',
       'status', "CustomerId"]

# %%
customer.columns = ["CustomerId", 'entity', 'name', 'surname', 'birth_date', 'sex',
       'country', 'state', 'purpose', 'deal_satisfaction', 'mortgage',
       'source']

# %%
properties.columns.values
# Out:
# array(['id', 'building', 'date_sale', 'type', 'property', 'area', 'price',
#        'status', 'CustomerId'], dtype=object)

# %%
properties.shape,customer.shape ## shape
# Out:
# ((267, 9), (162, 12))

# %%
customer
# Out:
#     CustomerId      entity     name     surname  birth_date sex country  \
# 0        C0110  Individual   Kareem         Liu   5/11/1968   F     USA
# 1        C0010  Individual  Trystan     Oconnor  11/26/1962   M     USA
# 2        C0132  Individual     Kale         Gay    4/7/1959   M     USA
# 3        C0137  Individual  Russell       Gross  11/25/1959   M     USA
# 4        C0174     Company  Marleez          Co  12/25/1974   M    USA
# ..         ...         ...      ...         ...         ...  ..     ...
# 157      C0170  Individual     Emmy       Singh   12/3/1979   F     USA
# 158      C0138  Individual    Colin      Campos   4/14/1942   M     USA
# 159      C0113  Individual     Anya  Stephenson   6/11/1959   F     USA
# 160      C0147  Individual   Parker       Poole  11/10/1951   M     USA
# 161      C0133  Individual     Ivan      Bright   9/15/1953   M     USA
#
#           state     purpose  deal_satisfaction mortgage   source
# 0    California        Home                  4      Yes  Website
# 1    California        Home                  1       No  Website
# 2    California        Home                  4      Yes   Agency
# 3    California        Home                  5       No  Website
# 4    California  Investment                  5       No  Website
# ..          ...         ...                ...      ...      ...
# 157    Virginia  Investment                  3      Yes   Agency
# 158  California        Home                  3       No  Website
# 159  California        Home                  4       No  Website
# 160  California        Home                  5       No  Website
# 161  California        Home                  4       No  Website
#
# [162 rows x 12 columns]

# %%
properties["CustomerId"] = properties["CustomerId"].apply(lambda x: x[1:-1])

# %%
df = pd.merge(customer,properties,how="outer",on="CustomerId") ## merging dataframes

# %%
df.head()
# Out:
#   CustomerId      entity     name  surname  birth_date sex country  \
# 0      C0110  Individual   Kareem      Liu   5/11/1968   F     USA
# 1      C0010  Individual  Trystan  Oconnor  11/26/1962   M     USA
# 2      C0132  Individual     Kale      Gay    4/7/1959   M     USA
# 3      C0137  Individual  Russell    Gross  11/25/1959   M     USA
# 4      C0137  Individual  Russell    Gross  11/25/1959   M     USA
#
#         state purpose  deal_satisfaction mortgage   source    id  building  \
# 0  California    Home                  4      Yes  Website  4051         4
# 1  California    Home                  1       No  Website  1045         1
# 2  California    Home                  4      Yes   Agency  3036         3
# 3  California    Home                  5       No  Website  4010         4
# 4  California    Home                  5       No  Website  4011         4
#
#    date_sale       type  property     area         price  status
# 0   3/1/2007  Apartment        51  1608.84  $496,266.41    Sold
# 1  10/1/2004  Apartment        45   756.21  $248,525.12    Sold
# 2  10/1/2007  Apartment        36  1127.76  $358,525.59    Sold
# 3  11/1/2007  Apartment        10   794.52  $223,917.34    Sold
# 4  11/1/2007  Apartment        11   794.52  $201,518.89    Sold

# %%
df.info() ## info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerId         267 non-null    object
#  1   entity             267 non-null    object
#  2   name               267 non-null    object
#  3   surname            267 non-null    object
#  4   birth_date         267 non-null    object
#  5   sex                267 non-null    object
#  6   country            267 non-null    object
#  7   state              267 non-null    object
#  8   purpose            267 non-null    object
#  9   deal_satisfaction  267 non-null    int64
#  10  mortgage           267 non-null    object
#  11  source             267 non-null    object
#  12  id                 267 non-null    int64
#  13  building           267 non-null    int64
#  14  date_sale          267 non-null    object
#  15  type               267 non-null    object
#  16  property           267 non-null    int64
#  17  area               267 non-null    float64
#  18  price              267 non-null    object
#  19  status             267 non-null    object
# dtypes: float64(1), int64(4), object(15)
# memory usage: 41.8+ KB

# %%
non_date = []  ## preprocessing
for i in range(len(df)):
    if "/" not in df["date_sale"][i]:
        non_date.append(i)

# %%
date = []
for i in range(len(df)):
    if i not in non_date:
        date.append(i)

# %%
df = df.iloc[date,:]

# %%
df["date_sale"] = pd.to_datetime(df["date_sale"],format='%m/%d/%Y') ### Date preprocessing
df["birth_date"] = pd.to_datetime(df["birth_date"],format='%m/%d/%Y')

# %%
df.head()
# Out:
#   CustomerId      entity     name  surname birth_date sex country       state  \
# 0      C0110  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      C0010  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      C0132  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area         price  status
# 0  Apartment        51  1608.84  $496,266.41    Sold
# 1  Apartment        45   756.21  $248,525.12    Sold
# 2  Apartment        36  1127.76  $358,525.59    Sold
# 3  Apartment        10   794.52  $223,917.34    Sold
# 4  Apartment        11   794.52  $201,518.89    Sold

# %%
df["sale_month"] = df["date_sale"].dt.month ### Extract from datetime variable
df["sale_year"] = df["date_sale"].dt.year
df["sale_weekday"] = df["date_sale"].dt.weekday

# %%
df["birth_month"] = df["birth_date"].dt.month ## Datetime series - data Extraction 
df["birth_year"] = df["birth_date"].dt.year
df["birth_weekday"] = df["birth_date"].dt.weekday

# %%
df = df.reset_index(drop=True) ## reseting index

# %%
df.head()
# Out:
#   CustomerId      entity     name  surname birth_date sex country       state  \
# 0      C0110  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      C0010  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      C0132  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area         price  status  sale_month  sale_year  \
# 0  Apartment        51  1608.84  $496,266.41    Sold            3       2007
# 1  Apartment        45   756.21  $248,525.12    Sold           10       2004
# 2  Apartment        36  1127.76  $358,525.59    Sold           10       2007
# 3  Apartment        10   794.52  $223,917.34    Sold           11       2007
# 4  Apartment        11   794.52  $201,518.89    Sold           11       2007
#
#    sale_weekday  birth_month  birth_year  birth_weekday
# 0             3            5        1968              5
# 1             4           11        1962              0
# 2             0            4        1959              1
# 3             3           11        1959              2
# 4             3           11        1959              2

# %%
def convert_price(x):
    return float(x[1:-1].split(",")[0]+x[0][1:-1].split(",")[1])

# %%
price = []  ## price column preprocessing
for i in range(len(df)):
    price.append(float(df["price"][i][1:].split(",")[0]+df["price"][i][1:].split(",")[1]))

# %%
df["price"] = price

# %%
df.head()
# Out:
#   CustomerId      entity     name  surname birth_date sex country       state  \
# 0      C0110  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      C0010  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      C0132  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area      price  status  sale_month  sale_year  \
# 0  Apartment        51  1608.84  496266.41   Sold            3       2007
# 1  Apartment        45   756.21  248525.12   Sold           10       2004
# 2  Apartment        36  1127.76  358525.59   Sold           10       2007
# 3  Apartment        10   794.52  223917.34   Sold           11       2007
# 4  Apartment        11   794.52  201518.89   Sold           11       2007
#
#    sale_weekday  birth_month  birth_year  birth_weekday
# 0             3            5        1968              5
# 1             4           11        1962              0
# 2             0            4        1959              1
# 3             3           11        1959              2
# 4             3           11        1959              2

# %%
for col in df.columns:
    print(col,":")
    print(df[col].unique())
    print(".......................")
# Out:
# CustomerId :
# ['C0110' 'C0010' 'C0132' 'C0137' 'C0174' 'C0088' 'C0079' 'C0149' 'C0064'
#  'C0068' 'C0006' 'C0055' 'C0016' 'C0121' 'C0074' 'C0032' 'C0093' 'C0076'
#  'C0165' 'C0153' 'C0129' 'C0162' 'C0071' 'C0069' 'C0005' 'C0144' 'C0020'
#  'C0101' 'C0128' 'C0033' 'C0171' 'C0095' 'C0123' 'C0015' 'C0084' 'C0019'
#  'C0053' 'C0080' 'C0070' 'C0051' 'C0022' 'C0127' 'C0081' 'C0104' 'C0073'
#  'C0168' 'C0169' 'C0039' 'C0086' 'C0036' 'C0045' 'C0105' 'C0119' 'C0012'
#  'C0065' 'C0054' 'C0172' 'C0029' 'C0098' 'C0142' 'C0135' 'C0037' 'C0134'
#  'C0091' 'C0018' 'C0085' 'C0061' 'C0066' 'C0156' 'C0043' 'C0112' 'C0145'
#  'C0047' 'C0082' 'C0007' 'C0052' 'C0041' 'C0004' 'C0118' 'C0030' 'C0154'
#  'C0125' 'C0115' 'C0078' 'C0151' 'C0111' 'C0014' 'C0103' 'C0024' 'C0166'
#  'C0067' 'C0122' 'C0107' 'C0003' 'C0099' 'C0160' 'C0013' 'C0059' 'C0120'
#  'C0150' 'C0140' 'C0002' 'C0096' 'C0159' 'C0163' 'C0100' 'C0155' 'C0049'
#  'C0148' 'C0146' 'C0034' 'C0141' 'C0008' 'C0131' 'C0089' 'C0157' 'C0114'
#  'C0124' 'C0158' 'C0175' 'C0023' 'C0164' 'C0058' 'C0062' 'C0042' 'C0048'
#  'C0083' 'C0025' 'C0087' 'C0094' 'C0038' 'C0011' 'C0139' 'C0021' 'C0106'
#  'C0040' 'C0035' 'C0126' 'C0136' 'C0109' 'C0028' 'C0057' 'C0130' 'C0044'
#  'C0056' 'C0077' 'C0031' 'C0072' 'C0063' 'C0017' 'C0009' 'C0075' 'C0027'
#  'C0060' 'C0001' 'C0090' 'C0108' 'C0170' 'C0138' 'C0113' 'C0147' 'C0133']
# .......................
# entity :
# ['Individual' 'Company']
# .......................
# name :
# ['Kareem' 'Trystan' 'Kale' 'Russell' 'Marleez' 'Yurem' 'Xavier' 'Kayden'
#  'Joaquin' 'Nicolas' 'Laci' 'Kylax' 'Harley' 'Esther' 'Jaylynn' 'Olivia'
#  'Antonio' 'Luke' 'Anahi' 'Camille' 'Jesus' 'Araceli' 'Cole' 'Alonso'
#  'Rodolfo' 'Joseph' 'Grant' 'Ava' 'Kyla' 'Alanna' 'Skylar' 'Rodrigo'
#  'Lydia' 'Lauryn' 'Diego' 'Victor' 'Scarlet' 'Janelle' 'Aleksandra'
#  'Conner' 'Zain' 'Maia' 'Jordyn' 'Diana' 'Kevin' 'Brisa' 'Mason' 'Derick'
#  'Jace' 'Jair' 'Matilda' 'Myla' 'Miguel' 'Bridger CAL' 'Mara' 'Erik'
#  'Henry' 'Kenyon' 'Oswaldo' 'Kassidy' 'Morgan' 'Tyler' 'Yesenia' 'Gordon'
#  'Melanie' 'Enrique' 'Helen' 'Isis' 'Kayley' 'Donavan' 'Augustus'
#  'Alejandra' 'Violet' 'Jaelyn' 'Tristian' 'Christian' 'Nora' 'Dangelo'
#  'Aiyana' 'Sidney' 'Kaitlin' 'Issac' 'Zaiden' 'Iris' 'Grace' 'Alessandra'
#  'Jamal' 'Irvin' 'Terry' 'Jacqueline' 'Brock' 'Curtis' 'Avah' 'Frank'
#  'Darien' 'Franklin' 'Elena' 'Jack' 'Emmett' 'Aniya' 'Kael' 'Kamden'
#  'Aniyah' 'Simon' 'Laurel' 'Trey' 'Myah' 'Nyla' 'Kole' 'Melany' 'Arthur'
#  'Kamila' 'Amanda' 'Erika' 'Jakobe' 'Sonia' 'Madeline' 'Bennett' 'Belinda'
#  'Johanna' 'Jaylen' 'Michael' 'Adriana' 'Julio' 'Abdiel' 'Warren' 'Luis'
#  'Mohammad' 'Davion' 'Logan' 'Kaylin' 'Ruben' 'Gianni' 'Emilie' 'Crystal'
#  'Annabel' 'Rachel' 'Madalyn' 'Michelle' 'Ezra' 'Ramiro' 'Emely' 'Hazel'
#  'Cedric' 'Dayton' 'Piotr' 'Memphis' 'Arabella' 'Sincere' 'Lara'
#  'Valentina' 'Kamd' 'Case' 'Van' 'Emmy' 'Colin' 'Anya' 'Parker' 'Ivan']
# .......................
# surname :
# ['Liu' 'Oconnor' 'Gay' 'Gross' 'Co' 'Wright' 'Faulkner' 'Olsen' 'Mullins'
#  'Navarro' 'Guerra' 'Lucero' 'Hickman' 'Oconnell' 'Porter' 'Lynn' 'Curry'
#  'Sharp' 'Obrien' 'Nelson' 'Taylor' 'Terrell' 'Gibson' 'Reeves' 'Weber'
#  'Phelps' 'Walker' 'Hess' 'Buchanan' 'Robinson' 'Tate' 'Patrick' 'Mendez'
#  'Jensen' 'Hendricks' 'Espinoza' 'Karenina' 'Huff' 'Horne' 'Chandler'
#  'Park' 'Hunt' 'Mata' 'Mckee' 'Gilbert' 'Li' 'Riggs' 'Johns' 'Madden'
#  'Ewing' 'Walter' 'Franco' 'Mora' 'Kennedy' 'Palmer' 'Vega' 'Glass' 'Carr'
#  'Marquez' 'Brown' 'Ramirez' 'Holland' 'Cardenas' 'Williamson' 'Rios'
#  'Nielsen' 'Flowers' 'Hinton' 'Greer' 'Nixon' 'Berger' 'Fuller' 'Costa'
#  'Lynch' 'Shea' 'Christensen' 'Cline' 'Owen' 'Edwards' 'Merritt' 'Larsen'
#  'Stein' 'Perry' 'Mueller' 'Ellis' 'Forbes' 'Grant' 'Fischer' 'Howard'
#  'Huang' 'Meyer' 'Dorsey' 'Mack' 'Petrova' 'Hanson' 'Estes' 'Miller'
#  'Anderson' 'Hurley' 'Stewart' 'Ali' 'Bennett' 'Benitez' 'Strong' 'Roman'
#  'Blake' 'Shannon' 'Glover' 'Bray' 'Collier' 'Simon' 'Steward' 'Bailey'
#  'Choi' 'Gallagher' 'Michael' 'Chen' 'Hogan' 'Fisher' 'Turner' 'Juarez'
#  'Shaffer' 'Leonard' 'Pugh' 'Crane' 'Irwin' 'Stout' 'Simmons' 'Villarreal'
#  'Melton' 'Fritz' 'Morrison' 'Wyatt' 'Robles' 'Cross' 'Mercer' 'Cameron'
#  'Lozano' 'Oneill' 'Watts' 'Ayers' 'Goodwin' 'Hatfield' 'Aleksandrov'
#  'Mcconnell' 'Ferrell' 'Hansen' 'Carrillo' 'Simpson' 'Sanchez' 'Charles'
#  'Singh' 'Campos' 'Stephenson' 'Poole' 'Bright']
# .......................
# birth_date :
# <DatetimeArray>
# ['1968-05-11 00:00:00', '1962-11-26 00:00:00', '1959-04-07 00:00:00',
#  '1959-11-25 00:00:00', '1974-12-25 00:00:00', '1957-03-06 00:00:00',
#  '1947-05-24 00:00:00', '1969-10-17 00:00:00', '1975-10-05 00:00:00',
#  '1966-06-17 00:00:00',
#  ...
#  '1967-01-19 00:00:00', '1983-02-24 00:00:00', '1965-01-24 00:00:00',
#  '1966-05-26 00:00:00', '1952-05-15 00:00:00', '1979-12-03 00:00:00',
#  '1942-04-14 00:00:00', '1959-06-11 00:00:00', '1951-11-10 00:00:00',
#  '1953-09-15 00:00:00']
# Length: 151, dtype: datetime64[ns]
# .......................
# sex :
# ['F' 'M']
# .......................
# country :
# ['USA' 'USA ' 'Canada' 'Germany' 'Belgium' 'Mexico' 'Russia' 'UK'
#  'Denmark']
# .......................
# state :
# ['California' 'Oregon' 'Arizona' 'Nevada' 'Colorado' 'Utah' 'Virginia'
#  'Wyoming' 'Kansas']
# .......................
# purpose :
# ['Home' 'Investment']
# .......................
# deal_satisfaction :
# [4 1 5 3 2]
# .......................
# mortgage :
# ['Yes' 'No']
# .......................
# source :
# ['Website' 'Agency' 'Client']
# .......................
# id :
# [4051 1045 3036 4010 4011 1013 1014 1019 1020 1022 1028 1034 1037 1042
#  5039 2019 2021 2027 2052 3006 3044 4025 4012 2004 2006 2047 1038 2038
#  1017 2001 2013 1016 3020 3029 2046 3041 4018 3012 3048 3017 2018 2014
#  3001 3043 1033 5027 5028 1012 2035 5013 1040 5051 3038 2051 1032 3049
#  1026 2020 3031 2025 3015 2029 1003 3033 2048 3025 2017 4049 4013 2032
#  5033 1024 2037 5016 3013 1009 2044 2040 3052 1007 1008 3022 4005 4041
#  2054 5034 3016 1025 3034 2036 2022 5040 2039 2002 5021 5022 2005 2028
#  1018 3007 3030 1046 1043 3032 2023 5036 3011 3026 3002 3004 2008 4030
#  3014 1049 3008 3040 1027 3023 2011 3046 3059 1044 3054 3055 2031 1015
#  3050 3010 3018 4006 5050 1002 3039 1047 3037 4031 3035 2015 2033 3009
#  5025 1031 3003 1021 4034 2056 4028 3042 3019 4040 4029 1006 3053 4022
#  2049 2007 2050 2026 2043 1011 5035 5030 2041 1035 5041 1023 5019 3027
#  1039 3005 4024 3021 1030 4035 2024 2057 2042 2016 2030 2009 2003 1041
#  1036 3047 1029 2010 1005 2012 2034 4023 4016 3028 5046 4019]
# .......................
# building :
# [4 1 3 5 2]
# .......................
# date_sale :
# <DatetimeArray>
# ['2007-03-01 00:00:00', '2004-10-01 00:00:00', '2007-10-01 00:00:00',
#  '2007-11-01 00:00:00', '2005-07-01 00:00:00', '2008-05-01 00:00:00',
#  '2007-04-01 00:00:00', '2007-02-01 00:00:00', '2007-12-01 00:00:00',
#  '2006-12-01 00:00:00', '2004-08-01 00:00:00', '2006-10-01 00:00:00',
#  '2005-02-01 00:00:00', '2004-03-01 00:00:00', '2006-02-01 00:00:00',
#  '2008-01-01 00:00:00', '2007-08-01 00:00:00', '2005-03-01 00:00:00',
#  '2007-05-01 00:00:00', '2007-09-01 00:00:00', '2006-04-01 00:00:00',
#  '2006-03-01 00:00:00', '2005-01-01 00:00:00', '2006-09-01 00:00:00',
#  '2005-06-01 00:00:00', '2007-06-01 00:00:00', '2007-01-01 00:00:00',
#  '2006-08-01 00:00:00', '2006-06-01 00:00:00', '2004-11-01 00:00:00',
#  '2005-12-01 00:00:00', '2006-11-01 00:00:00', '2007-07-01 00:00:00',
#  '2008-12-01 00:00:00', '2004-06-01 00:00:00', '2005-08-01 00:00:00',
#  '2006-07-01 00:00:00', '2006-05-01 00:00:00', '2005-09-01 00:00:00',
#  '2010-05-01 00:00:00', '2005-04-01 00:00:00', '2005-11-01 00:00:00',
#  '2005-10-01 00:00:00']
# Length: 43, dtype: datetime64[ns]
# .......................
# type :
# ['Apartment' 'Office']
# .......................
# property :
# [51 45 36 10 11 13 14 19 20 22 28 34 37 42 39 21 27 52  6 44 25 12  4 47
#  38 17  1 16 29 46 41 18 48 43 33 35 40 32 49 26 31 15  3 24  9  7  8  5
#  54  2 30 23 59 55 50 56 53 57]
# .......................
# area :
# [1608.84  756.21 1127.76  794.52  743.09  827.87 1160.36  625.8   798.28
#   649.8   785.48 1615.29 1132.06  720.38  733.19 1121.95  649.69 1307.45
#  1604.75 1434.09  587.28  782.25  781.07  928.16  743.41  927.83 1109.25
#   579.75 1128.4   618.38  790.54 1596.35 1383.84 1283.45  720.7   717.05
#   670.89  923.21  747.5  1336.93  723.83  798.5  1200.82  800.96  722.96
#   775.69 1137.44 1305.62 1203.29  697.89  720.81 1942.5  1057.92  675.19
#   701.66 1375.45 1171.55 1222.34  977.87 1093.   1238.58 1479.72  723.93
#   618.16 1400.95  680.57  736.63  670.24 1288.62  957.53 1110.32 1396.86
#   927.08  669.16  410.71]
# .......................
# price :
# [496266.41 248525.12 358525.59 223917.34 201518.89 206958.71 206445.42
#  239341.58 398903.42 210745.17 331154.88 204434.68 189194.31 204027.09
#  195874.94 177555.06 217748.48 247739.44 484458.03 356506.37 197869.36
#  236608.95 290031.26 168834.04 396973.83 214631.68 207581.43 529317.28
#  432679.91 169158.29 236639.56 224076.84 258572.48 310831.21 253831.02
#  239248.75 310832.59 210824.06 249075.66 205098.21 275394.25 336695.25
#  171262.65 299159.14 412856.56 269075.3  223577.32 300385.62 192092.24
#  188743.11 234172.39 249591.99 464549.19 376964.62 215410.28 338181.18
#  179674.08 241671.52 407214.29 315733.15 207281.59 310223.29 193660.62
#  200300.63 220865.   296483.14 199054.2  388515.14 197053.51 306878.46
#  240539.35 235762.34 229581.78 278575.87 253025.78 317196.4  264142.16
#  250773.15 224463.87 291494.36 250312.53 246050.4  354553.23 344530.89
#  402081.8  306363.64 252053.03 226342.8  382041.13 256821.64 460001.26
#  344568.74 228410.05 293876.27 209280.91 234750.59 287466.41 257183.48
#  195153.16 191389.87 231552.33 215774.28 503790.23 377313.56 242740.66
#  219373.41 286433.57 203491.85 212520.83 261871.7  210038.7  204286.67
#  310577.04 346906.89 467083.31 219865.76 204292.49 276759.18 198591.85
#  225401.62 252185.99 367976.46 229464.71 200719.02 380809.52 452667.01
#  208930.81 248274.31 294807.65 293828.69 222138.72 390494.27 410932.67
#  312211.14 448134.27 204808.16 200678.75 269278.57 228170.03 205085.4
#  222867.42 165430.28 265467.68 233142.8  218585.92 243052.59 248422.66
#  213942.56 230154.53 241620.48 200148.89 198841.7  190119.5  263790.81
#  323915.81 196142.19 297008.97 198075.99 355073.4  222947.21 261742.74
#  357538.2  225050.52 238811.06 263123.42 261579.89 153466.71 245572.79
#  196220.05 258015.61 372001.7  225290.22 246172.68 217786.38 456919.46
#  382277.15 220606.28 212265.67 214341.34 237060.15 289727.99 480545.81
#  317473.86 188273.73 246331.9  326885.34 117564.07 237207.68 252927.84
#  235633.26 244820.67 206631.81 230216.22 226578.51]
# .......................
# status :
# [' Sold ']
# .......................
# sale_month :
# [ 3 10 11  7  5  4  2 12  8  1  9  6]
# .......................
# sale_year :
# [2007 2004 2005 2008 2006 2010]
# .......................
# sale_weekday :
# [3 4 0 6 5 1 2]
# .......................
# birth_month :
# [ 5 11  4 12  3 10  6  8  9  1  2  7]
# .......................
# birth_year :
# [1968 1962 1959 1974 1957 1947 1969 1975 1966 1956 1941 1939 1977 1967
#  1938 1958 1963 1937 1976 1952 1965 1973 1931 1964 1970 1971 1940 1954
#  1933 1960 1972 1942 1985 1953 1980 1948 1949 1943 1981 1979 1936 1982
#  1951 1978 1955 1950 1946 1932 1986 1983]
# .......................
# birth_weekday :
# [5 0 1 2 4 6 3]
# .......................

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerId         195 non-null    object
#  1   entity             195 non-null    object
#  2   name               195 non-null    object
#  3   surname            195 non-null    object
#  4   birth_date         195 non-null    datetime64[ns]
#  5   sex                195 non-null    object
#  6   country            195 non-null    object
#  7   state              195 non-null    object
#  8   purpose            195 non-null    object
#  9   deal_satisfaction  195 non-null    int64
#  10  mortgage           195 non-null    object
#  11  source             195 non-null    object
#  12  id                 195 non-null    int64
#  13  building           195 non-null    int64
#  14  date_sale          195 non-null    datetime64[ns]
#  15  type               195 non-null    object
#  16  property           195 non-null    int64
#  17  area               195 non-null    float64
#  18  price              195 non-null    float64
#  19  status             195 non-null    object
#  20  sale_month         195 non-null    int32
#  21  sale_year          195 non-null    int32
#  22  sale_weekday       195 non-null    int32
#  23  birth_month        195 non-null    int32
#  24  birth_year         195 non-null    int32
#  25  birth_weekday      195 non-null    int32
# dtypes: datetime64[ns](2), float64(2), int32(6), int64(4), object(12)
# memory usage: 35.2+ KB

# %% [markdown]
# ### Descriptive Statistics

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
### Start by examining how many building types there are in the data set.
df["type"].value_counts().plot.bar()
plt.title('How many types of Buildings available')
plt.show()

# %%
df["mortgage_df"] = df["mortgage"].replace({"Yes":1,"No":0})

# %%
### Select columns of interest which to examine the totals by building type. Make a list with
### those variables, including building as the index variable. They are sold and mortgage
sold = df[df["status"]==' Sold ']
interest = ["type","mortgage_df"]

# %%
sold[interest]
# Out:
#           type  mortgage_df
# 0    Apartment            1
# 1    Apartment            0
# 2    Apartment            1
# 3    Apartment            0
# 4    Apartment            0
# ..         ...          ...
# 190  Apartment            1
# 191  Apartment            0
# 192  Apartment            0
# 193  Apartment            0
# 194  Apartment            0
#
# [195 rows x 2 columns]

# %%
building = df.groupby("building")["price"].max() ### What is the highest priced building?

# %%
building.plot.bar()
plt.title("highest priced building")
plt.show()

# %%
df["status"].value_counts()
# Out:
# status
#  Sold     195
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerId         195 non-null    object
#  1   entity             195 non-null    object
#  2   name               195 non-null    object
#  3   surname            195 non-null    object
#  4   birth_date         195 non-null    datetime64[ns]
#  5   sex                195 non-null    object
#  6   country            195 non-null    object
#  7   state              195 non-null    object
#  8   purpose            195 non-null    object
#  9   deal_satisfaction  195 non-null    int64
#  10  mortgage           195 non-null    object
#  11  source             195 non-null    object
#  12  id                 195 non-null    int64
#  13  building           195 non-null    int64
#  14  date_sale          195 non-null    datetime64[ns]
#  15  type               195 non-null    object
#  16  property           195 non-null    int64
#  17  area               195 non-null    float64
#  18  price              195 non-null    float64
#  19  status             195 non-null    object
#  20  sale_month         195 non-null    int32
#  21  sale_year          195 non-null    int32
#  22  sale_weekday       195 non-null    int32
#  23  birth_month        195 non-null    int32
#  24  birth_year         195 non-null    int32
#  25  birth_weekday      195 non-null    int32
#  26  mortgage_df        195 non-null    int64
# dtypes: datetime64[ns](2), float64(2), int32(6), int64(5), object(12)
# memory usage: 36.7+ KB

# %%
df[interest]
# Out:
#           type  mortgage_df
# 0    Apartment            1
# 1    Apartment            0
# 2    Apartment            1
# 3    Apartment            0
# 4    Apartment            0
# ..         ...          ...
# 190  Apartment            1
# 191  Apartment            0
# 192  Apartment            0
# 193  Apartment            0
# 194  Apartment            0
#
# [195 rows x 2 columns]

# %%
df[interest].groupby("type").agg({"mortgage_df":"sum"}).plot.bar()
plt.title("Building Type wise property and status")
plt.show()

# %%
columns_for_averages = ['type', 'area', 'price', 'deal_satisfaction']
averages_df = df[columns_for_averages]

# %%
averages_df
# Out:
#           type     area      price  deal_satisfaction
# 0    Apartment  1608.84  496266.41                  4
# 1    Apartment   756.21  248525.12                  1
# 2    Apartment  1127.76  358525.59                  4
# 3    Apartment   794.52  223917.34                  5
# 4    Apartment   794.52  201518.89                  5
# ..         ...      ...        ...                ...
# 190  Apartment   794.52  235633.26                  3
# 191  Apartment   794.52  244820.67                  3
# 192  Apartment   781.07  206631.81                  4
# 193  Apartment   798.28  230216.22                  5
# 194  Apartment   733.19  226578.51                  4
#
# [195 rows x 4 columns]

# %%
averages_df.groupby("type").mean()
# Out:
#                  area          price  deal_satisfaction
# type
# Apartment  901.608564  270038.541755           3.590426
# Office     853.097143  253213.361429           3.857143

# %%
averages_df.groupby("type").mean().plot.barh() ## averages of dataframes
plt.title("Building Type - area&price&deal_statisfication")
plt.show()

# %%
totals_by_building_type = df.groupby('type').agg({'price': 'sum', 'mortgage_df': 'sum'}) ## total by building type
print(totals_by_building_type)
# Out:
#                  price  mortgage_df
# type
# Apartment  50767245.85           58
# Office      1772493.53            4

# %%
### Determine the average values of area , price , and deal satisfaction per building type
columns_for_averages = ['type', 'area', 'price', 'deal_satisfaction']
averages_df = df[columns_for_averages]

averages_by_building_type = averages_df.groupby('type').mean()
print(averages_by_building_type)
# Out:
#                  area          price  deal_satisfaction
# type
# Apartment  901.608564  270038.541755           3.590426
# Office     853.097143  253213.361429           3.857143

# %%
df.country.value_counts() # countries in data
# Out:
# country
# USA        165
# USA         12
# Canada       7
# Russia       4
# Belgium      2
# UK           2
# Germany      1
# Mexico       1
# Denmark      1
# Name: count, dtype: int64

# %%
### interest
interest = ["mortgage_df","price","country"]

# %%
df[interest]
# Out:
#      mortgage_df      price country
# 0              1  496266.41     USA
# 1              0  248525.12     USA
# 2              1  358525.59     USA
# 3              0  223917.34     USA
# 4              0  201518.89     USA
# ..           ...        ...     ...
# 190            1  235633.26     USA
# 191            0  244820.67     USA
# 192            0  206631.81     USA
# 193            0  230216.22     USA
# 194            0  226578.51     USA
#
# [195 rows x 3 columns]

# %%
df[interest].groupby("country").agg({"mortgage_df":"sum","price":"sum"})
# Out:
#          mortgage_df        price
# country
# Belgium            0    458150.94
# Canada             0   1918485.69
# Denmark            0    257183.48
# Germany            0    205098.21
# Mexico             0    338181.18
# Russia             1   1115315.34
# UK                 0    440285.36
# USA               61  44666887.16
# USA                0   3140152.02

# %%
### Determine the average values of area , price , and deal satisfaction per building type
columns_for_averages = ['country', 'area', 'price', 'deal_satisfaction']
averages_df = df[columns_for_averages]

averages_by_building_type = averages_df.groupby('country').mean()
print(averages_by_building_type)
# Out:
#                 area          price  deal_satisfaction
# country
# Belgium   852.730000  229075.470000            3.00000
# Canada    917.382857  274069.384286            5.00000
# Denmark   785.480000  257183.480000            1.00000
# Germany   743.410000  205098.210000            5.00000
# Mexico   1283.450000  338181.180000            3.00000
# Russia    903.757500  278828.835000            2.50000
# UK        739.480000  220142.680000            4.00000
# USA       901.756545  270708.407030            3.49697
# USA       887.565833  261679.335000            4.75000

# %%
df.state.value_counts() # countries in data
# Out:
# state
# California    134
# Nevada         17
# Oregon         11
# Arizona        11
# Colorado       11
# Utah            5
# Virginia        4
# Wyoming         1
# Kansas          1
# Name: count, dtype: int64

# %%
### interest
interest = ["mortgage_df","price","state"]
df[interest]
# Out:
#      mortgage_df      price       state
# 0              1  496266.41  California
# 1              0  248525.12  California
# 2              1  358525.59  California
# 3              0  223917.34  California
# 4              0  201518.89  California
# ..           ...        ...         ...
# 190            1  235633.26    Virginia
# 191            0  244820.67  California
# 192            0  206631.81  California
# 193            0  230216.22  California
# 194            0  226578.51  California
#
# [195 rows x 3 columns]

# %%
df[interest].groupby("state").agg({"mortgage_df":"sum","price":"sum"})
# Out:
#             mortgage_df        price
# state
# Arizona               3   2854796.41
# California           42  37286264.93
# Colorado              5   2570287.08
# Kansas                0    252185.99
# Nevada                8   4720038.60
# Oregon                1   2602526.55
# Utah                  1   1188776.40
# Virginia              2    860576.75
# Wyoming               0    204286.67

# %%
### Determine the average values of area , price , and deal satisfaction per building type
columns_for_averages = ['state', 'area', 'price', 'deal_satisfaction']
averages_df = df[columns_for_averages]

averages_by_building_type = averages_df.groupby('state').mean()
print(averages_by_building_type)
# Out:
#                   area          price  deal_satisfaction
# state
# Arizona     841.627273  259526.946364           3.363636
# California  932.396567  278255.708433           3.738806
# Colorado    777.010909  233662.461818           3.181818
# Kansas      923.210000  252185.990000           3.000000
# Nevada      921.692941  277649.329412           3.235294
# Oregon      766.954545  236593.322727           3.090909
# Utah        814.986000  237755.280000           3.200000
# Virginia    730.712500  215144.187500           4.500000
# Wyoming     701.660000  204286.670000           3.000000

# %%
import pandas as pd

# Assuming df is your DataFrame
# Assuming 'price' is the column you want to calculate the cumulative sum for

df['cumulative_price'] = df['price'].cumsum()

# Display the DataFrame with the cumulative sum column
print(df[['price', 'cumulative_price']])
# Out:
#          price  cumulative_price
# 0    496266.41         496266.41
# 1    248525.12         744791.53
# 2    358525.59        1103317.12
# 3    223917.34        1327234.46
# 4    201518.89        1528753.35
# ..         ...               ...
# 190  235633.26       51631492.17
# 191  244820.67       51876312.84
# 192  206631.81       52082944.65
# 193  230216.22       52313160.87
# 194  226578.51       52539739.38
#
# [195 rows x 2 columns]

# %%
df["Age"] = df["sale_year"]-df["birth_year"]

# %%
df.head()
# Out:
#   CustomerId      entity     name  surname birth_date sex country       state  \
# 0      C0110  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      C0010  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      C0132  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area      price  status  sale_month  sale_year  \
# 0  Apartment        51  1608.84  496266.41   Sold            3       2007
# 1  Apartment        45   756.21  248525.12   Sold           10       2004
# 2  Apartment        36  1127.76  358525.59   Sold           10       2007
# 3  Apartment        10   794.52  223917.34   Sold           11       2007
# 4  Apartment        11   794.52  201518.89   Sold           11       2007
#
#    sale_weekday  birth_month  birth_year  birth_weekday  mortgage_df  \
# 0             3            5        1968              5            1
# 1             4           11        1962              0            0
# 2             0            4        1959              1            1
# 3             3           11        1959              2            0
# 4             3           11        1959              2            0
#
#    cumulative_price  Age
# 0         496266.41   39
# 1         744791.53   42
# 2        1103317.12   48
# 3        1327234.46   48
# 4        1528753.35   48

# %%
interval = []
for i in df["Age"]:
    if 10 < i < 20:
        interval.append("10-20")
    elif 20 < i < 30:
        interval.append("20-30")
    elif 30 < i < 40:
        interval.append("30-40")
    elif 40 < i < 50:
        interval.append("40-50")
    elif 50 < i < 60:
        interval.append("50-60")
    elif 60 < i < 70:
        interval.append("60-70")
    else:
        interval.append("70-80")

# %%
df["Age_Interval"] = interval

# %%
df.head()
# Out:
#   CustomerId      entity     name  surname birth_date sex country       state  \
# 0      C0110  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      C0010  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      C0132  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      C0137  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area      price  status  sale_month  sale_year  \
# 0  Apartment        51  1608.84  496266.41   Sold            3       2007
# 1  Apartment        45   756.21  248525.12   Sold           10       2004
# 2  Apartment        36  1127.76  358525.59   Sold           10       2007
# 3  Apartment        10   794.52  223917.34   Sold           11       2007
# 4  Apartment        11   794.52  201518.89   Sold           11       2007
#
#    sale_weekday  birth_month  birth_year  birth_weekday  mortgage_df  \
# 0             3            5        1968              5            1
# 1             4           11        1962              0            0
# 2             0            4        1959              1            1
# 3             3           11        1959              2            0
# 4             3           11        1959              2            0
#
#    cumulative_price  Age Age_Interval
# 0         496266.41   39        30-40
# 1         744791.53   42        40-50
# 2        1103317.12   48        40-50
# 3        1327234.46   48        40-50
# 4        1528753.35   48        40-50

# %%
df.groupby("Age_Interval")["Age_Interval"].count().plot.bar(color="gray") ### Age-Distribution
plt.xlabel("Age")
plt.title("Age Distribution")
plt.show()

# %%
df["Age"].plot.hist(bins=10,color="gray") ### Age-Distribution
plt.xlabel("Age")
plt.title("Age Distribution")
plt.show()

# %%
df.groupby("Age")["price"].sum().plot.hist(bins=10,color="grey") ### Age-price intervals
plt.xlabel("price")
plt.title("Age-price interval")
plt.show()

# %%
age_properties = df.groupby("Age")["price"].sum().reset_index()

# %%
age_properties.corr()
# Out:
#             Age     price
# Age    1.000000 -0.262484
# price -0.262484  1.000000

# %%
import seaborn as sns
sns.heatmap(age_properties.corr(),annot=True)
plt.title("correlation map of age_properties")
plt.show()

# %%
age_properties.cov()
# Out:
#                 Age         price
# Age    2.329802e+02 -2.958313e+06
# price -2.958313e+06  5.452098e+11

# %%
plt.scatter(age_properties["Age"],age_properties["price"])
plt.xlabel("Age")
plt.ylabel("price")
plt.title("Age and Price relationship")
plt.show()

# %%
### What is the average deal satisfaction for each country? How does it look by state?
df.groupby("country")["deal_satisfaction"].mean().sort_values().plot.barh(color="orange")
plt.title("Country - deal_statisfaction")
plt.show()

# %%
### What is the monthly revenue of the company?
df.groupby("sale_month")["price"].sum().plot(color="yellow")
# Out:
# <Axes: xlabel='sale_month'>

# %%
### How many apartments are sold in each state?
df[(df["status"]==' Sold ')].groupby("state")["type"].count().plot.barh(color="purple")
plt.title("apartments are sold in each state")
plt.show()

# %%
### What is the age distribution for customers? (Use the same age intervals or number of bins from the data analysis stage.)
df["Age"].plot.hist(bins=10,color="black")
plt.xlabel("age")
plt.title("Age distribution")
plt.show()

# %%
### What are the yearly sales for each building
df.groupby("sale_year")["building"].sum().plot.bar(stacked=True)
plt.xlabel("date")
plt.title("yearly sales for each building")
plt.show()

# %% [markdown]
# ### Data Modeling:
#     * Build machine learning models and evaluate it
#     Evaluation:
#      * Evaluation metrics (accuracy-95%) will be acceptable level
#      * tune the model

# %%
df.columns
# Out:
# Index(['CustomerId', 'entity', 'name', 'surname', 'birth_date', 'sex',
#        'country', 'state', 'purpose', 'deal_satisfaction', 'mortgage',
#        'source', 'id', 'building', 'date_sale', 'type', 'property', 'area',
#        'price', 'status', 'sale_month', 'sale_year', 'sale_weekday',
#        'birth_month', 'birth_year', 'birth_weekday', 'mortgage_df',
#        'cumulative_price', 'Age', 'Age_Interval'],
#       dtype='object')

# %%
ts = df.reset_index().sort_values(by="date_sale",ascending=True).set_index("date_sale")["price"]
ts.head()
# Out:
# date_sale
# 2004-03-01    169158.29
# 2004-03-01    410932.67
# 2004-03-01    117564.07
# 2004-06-01    229464.71
# 2004-06-01    377313.56
# Name: price, dtype: float64

# %%
ts.plot()
# Out:
# <Axes: xlabel='date_sale'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt
from statsmodels.tsa.seasonal import seasonal_decompose


# Visualize your data
plt.figure(figsize=(10, 6))
plt.plot(ts.index, ts, marker='o', linestyle='-')
plt.title('Time Series Data: Date vs Sale')
plt.xlabel('Date')
plt.ylabel('Sale')
plt.show()

result = seasonal_decompose(ts, model='additive', period=1)  # Adjust 'period' as needed

# Visualize the components
plt.figure(figsize=(12, 8))
plt.subplot(4, 1, 1)
plt.plot(result.observed, label='Observed')
plt.legend()

plt.subplot(4, 1, 2)
plt.plot(result.trend, label='Trend')
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(result.seasonal, label='Seasonal')
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(result.resid, label='Residual')
plt.legend()

plt.tight_layout()
plt.show()

# Train-test split
train_size = int(len(ts) * 0.8)
train, test = ts[:train_size], ts[train_size:]

# SARIMA model
order = (1, 1, 1)  # Non-seasonal order (p, d, q)
seasonal_order = (1, 1, 1, 12)  # Seasonal order (P, D, Q, s)

model = SARIMAX(train, order=order, seasonal_order=seasonal_order, enforce_stationarity=False, enforce_invertibility=False)
fit_model = model.fit(disp=False)

# Forecast
predictions = fit_model.get_forecast(steps=len(test))
predicted_values = predictions.predicted_mean

# Evaluate the model
mse = mean_squared_error(test, predicted_values)
rmse = sqrt(mse)
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'r2 score: {r2_score(test,predicted_values)}')

# Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(train.index, train, label='Train')
plt.plot(test.index, test, label='Test')
plt.plot(test.index, predicted_values, label='Predicted', linestyle='--', color='red')
plt.title('SARIMA Model Forecasting')
plt.xlabel('Date')
plt.ylabel('Sale')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 10484889401.422995
# Root Mean Squared Error (RMSE): 102395.748942146
# r2 score: -1.1767434545591247

# %%
df = df.drop(["CustomerId","Age_Interval"],axis=1)
df.head()
# Out:
#        entity     name  surname birth_date sex country       state purpose  \
# 0  Individual   Kareem      Liu 1968-05-11   F     USA  California    Home
# 1  Individual  Trystan  Oconnor 1962-11-26   M     USA  California    Home
# 2  Individual     Kale      Gay 1959-04-07   M     USA  California    Home
# 3  Individual  Russell    Gross 1959-11-25   M     USA  California    Home
# 4  Individual  Russell    Gross 1959-11-25   M     USA  California    Home
#
#    deal_satisfaction mortgage   source    id  building  date_sale       type  \
# 0                  4      Yes  Website  4051         4 2007-03-01  Apartment
# 1                  1       No  Website  1045         1 2004-10-01  Apartment
# 2                  4      Yes   Agency  3036         3 2007-10-01  Apartment
# 3                  5       No  Website  4010         4 2007-11-01  Apartment
# 4                  5       No  Website  4011         4 2007-11-01  Apartment
#
#    property     area      price  status  sale_month  sale_year  sale_weekday  \
# 0        51  1608.84  496266.41   Sold            3       2007             3
# 1        45   756.21  248525.12   Sold           10       2004             4
# 2        36  1127.76  358525.59   Sold           10       2007             0
# 3        10   794.52  223917.34   Sold           11       2007             3
# 4        11   794.52  201518.89   Sold           11       2007             3
#
#    birth_month  birth_year  birth_weekday  mortgage_df  cumulative_price  Age
# 0            5        1968              5            1         496266.41   39
# 1           11        1962              0            0         744791.53   42
# 2            4        1959              1            1        1103317.12   48
# 3           11        1959              2            0        1327234.46   48
# 4           11        1959              2            0        1528753.35   48

# %%
df = df.drop([111],axis=0)

# %%
df = df.drop([120],axis=0)
df["state"].value_counts()
# Out:
# state
# California    134
# Nevada         17
# Oregon         11
# Arizona        11
# Colorado       11
# Utah            5
# Virginia        4
# Name: count, dtype: int64

# %%
df.reset_index(inplace=True)

# %%
df = df[df["country"]=="USA"]

# %%
df["source"].value_counts()
# Out:
# source
# Website    98
# Agency     48
# Client     17
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    index      entity     name  surname birth_date sex country       state  \
# 0      0  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      1  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      2  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      3  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      4  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area      price  status  sale_month  sale_year  \
# 0  Apartment        51  1608.84  496266.41   Sold            3       2007
# 1  Apartment        45   756.21  248525.12   Sold           10       2004
# 2  Apartment        36  1127.76  358525.59   Sold           10       2007
# 3  Apartment        10   794.52  223917.34   Sold           11       2007
# 4  Apartment        11   794.52  201518.89   Sold           11       2007
#
#    sale_weekday  birth_month  birth_year  birth_weekday  mortgage_df  \
# 0             3            5        1968              5            1
# 1             4           11        1962              0            0
# 2             0            4        1959              1            1
# 3             3           11        1959              2            0
# 4             3           11        1959              2            0
#
#    cumulative_price  Age
# 0         496266.41   39
# 1         744791.53   42
# 2        1103317.12   48
# 3        1327234.46   48
# 4        1528753.35   48

# %%
categorical_data = [col for col in df.columns if df[col].dtypes=="O"]
numerical_data = [col for col in df.columns if df[col].dtypes!="O"]

# %%
categorical_data,numerical_data
# Out:
# (['entity',
#   'name',
#   'surname',
#   'sex',
#   'country',
#   'state',
#   'purpose',
#   'mortgage',
#   'source',
#   'type',
#   'status'],
#  ['index',
#   'birth_date',
#   'deal_satisfaction',
#   'id',
#   'building',
#   'date_sale',
#   'property',
#   'area',
#   'price',
#   'sale_month',
#   'sale_year',
#   'sale_weekday',
#   'birth_month',
#   'birth_year',
#   'birth_weekday',
#   'mortgage_df',
#   'cumulative_price',
#   'Age'])

# %%
# ### Label Encoding
# from sklearn.preprocessing import LabelEncoder
# labels = {}
# for i in categorical_data:
#     label = LabelEncoder()
#     df[i] = label.fit_transform(df[i])
#     labels[i] = label

# %%
# for col in ["sale_year","birth_year"]:
#     label = LabelEncoder()
#     df[col] = label.fit_transform(df[col])
#     labels[col] = label

# %%
# import pickle
# with open("labels.pkl","wb") as file:
#     pickle.dump(label,file)

# %%
df.head()
# Out:
#    index      entity     name  surname birth_date sex country       state  \
# 0      0  Individual   Kareem      Liu 1968-05-11   F     USA  California
# 1      1  Individual  Trystan  Oconnor 1962-11-26   M     USA  California
# 2      2  Individual     Kale      Gay 1959-04-07   M     USA  California
# 3      3  Individual  Russell    Gross 1959-11-25   M     USA  California
# 4      4  Individual  Russell    Gross 1959-11-25   M     USA  California
#
#   purpose  deal_satisfaction mortgage   source    id  building  date_sale  \
# 0    Home                  4      Yes  Website  4051         4 2007-03-01
# 1    Home                  1       No  Website  1045         1 2004-10-01
# 2    Home                  4      Yes   Agency  3036         3 2007-10-01
# 3    Home                  5       No  Website  4010         4 2007-11-01
# 4    Home                  5       No  Website  4011         4 2007-11-01
#
#         type  property     area      price  status  sale_month  sale_year  \
# 0  Apartment        51  1608.84  496266.41   Sold            3       2007
# 1  Apartment        45   756.21  248525.12   Sold           10       2004
# 2  Apartment        36  1127.76  358525.59   Sold           10       2007
# 3  Apartment        10   794.52  223917.34   Sold           11       2007
# 4  Apartment        11   794.52  201518.89   Sold           11       2007
#
#    sale_weekday  birth_month  birth_year  birth_weekday  mortgage_df  \
# 0             3            5        1968              5            1
# 1             4           11        1962              0            0
# 2             0            4        1959              1            1
# 3             3           11        1959              2            0
# 4             3           11        1959              2            0
#
#    cumulative_price  Age
# 0         496266.41   39
# 1         744791.53   42
# 2        1103317.12   48
# 3        1327234.46   48
# 4        1528753.35   48

# %%
for col in df[["deal_satisfaction","property","area","sale_month","sale_weekday", "birth_month","birth_year","birth_weekday","Age"]].columns:
    print(df[col].value_counts())
    print("------------------")
# Out:
# deal_satisfaction
# 5    51
# 4    38
# 3    33
# 2    24
# 1    17
# Name: count, dtype: int64
# ------------------
# property
# 41    5
# 40    5
# 35    5
# 30    5
# 16    4
# 34    4
# 18    4
# 33    4
# 29    4
# 22    4
# 31    4
# 13    4
# 28    4
# 12    4
# 39    4
# 11    4
# 10    4
# 36    4
# 25    3
# 24    3
# 49    3
# 51    3
# 9     3
# 7     3
# 2     3
# 21    3
# 23    3
# 19    3
# 15    3
# 26    3
# 46    3
# 27    3
# 43    3
# 47    3
# 38    3
# 20    2
# 4     2
# 6     2
# 17    2
# 1     2
# 3     2
# 54    2
# 8     2
# 50    2
# 44    2
# 48    2
# 37    2
# 14    2
# 5     2
# 53    1
# 56    1
# 45    1
# 55    1
# 59    1
# 52    1
# 32    1
# 42    1
# Name: count, dtype: int64
# ------------------
# area
# 781.07     13
# 798.28     11
# 794.52     10
# 785.48      9
# 923.21      6
#            ..
# 1305.62     1
# 1203.29     1
# 1942.50     1
# 1132.06     1
# 410.71      1
# Name: count, Length: 70, dtype: int64
# ------------------
# sale_month
# 11    25
# 3     20
# 10    19
# 12    17
# 8     16
# 6     15
# 9     13
# 5     11
# 4      8
# 1      7
# 2      6
# 7      6
# Name: count, dtype: int64
# ------------------
# sale_weekday
# 3    41
# 0    24
# 1    22
# 4    20
# 6    20
# 2    18
# 5    18
# Name: count, dtype: int64
# ------------------
# birth_month
# 12    27
# 6     18
# 3     14
# 8     14
# 9     14
# 7     13
# 11    12
# 2     12
# 4     11
# 10    10
# 1     10
# 5      8
# Name: count, dtype: int64
# ------------------
# birth_year
# 1974    12
# 1959    10
# 1962     8
# 1968     6
# 1973     6
# 1967     6
# 1964     5
# 1975     5
# 1966     5
# 1953     5
# 1963     5
# 1958     5
# 1938     4
# 1948     4
# 1977     4
# 1941     4
# 1957     4
# 1939     3
# 1949     3
# 1972     3
# 1942     3
# 1979     3
# 1970     3
# 1969     3
# 1965     3
# 1956     3
# 1952     3
# 1976     3
# 1978     3
# 1951     2
# 1936     2
# 1981     2
# 1943     2
# 1971     2
# 1985     2
# 1947     2
# 1960     2
# 1933     2
# 1980     1
# 1954     1
# 1940     1
# 1982     1
# 1931     1
# 1937     1
# 1955     1
# 1950     1
# 1946     1
# 1986     1
# 1983     1
# Name: count, dtype: int64
# ------------------
# birth_weekday
# 1    30
# 3    28
# 5    27
# 4    22
# 2    21
# 6    21
# 0    14
# Name: count, dtype: int64
# ------------------
# Age
# 48    11
# 31     8
# 30     7
# 56     6
# 41     6
# 55     6
# 34     6
# 44     6
# 40     5
# 45     5
# 49     5
# 29     5
# 39     5
# 33     5
# 37     5
# 42     4
# 54     4
# 26     4
# 65     4
# 69     4
# 43     4
# 32     4
# 38     4
# 66     4
# 47     3
# 22     3
# 67     3
# 51     3
# 35     2
# 73     2
# 59     2
# 50     2
# 71     2
# 61     2
# 57     2
# 27     2
# 53     1
# 19     1
# 68     1
# 64     1
# 52     1
# 25     1
# 76     1
# 28     1
# Name: count, dtype: int64
# ------------------

# %%
for col in df[["deal_satisfaction","property","area","sale_month","sale_weekday", "birth_month","birth_year","birth_weekday","Age"]].columns:
    if df[col].nunique()<=12:
        print(df[col].value_counts())
        print("------------------")
    else:
        print(df[col].nunique())
# Out:
# deal_satisfaction
# 5    51
# 4    38
# 3    33
# 2    24
# 1    17
# Name: count, dtype: int64
# ------------------
# 57
# 70
# sale_month
# 11    25
# 3     20
# 10    19
# 12    17
# 8     16
# 6     15
# 9     13
# 5     11
# 4      8
# 1      7
# 2      6
# 7      6
# Name: count, dtype: int64
# ------------------
# sale_weekday
# 3    41
# 0    24
# 1    22
# 4    20
# 6    20
# 2    18
# 5    18
# Name: count, dtype: int64
# ------------------
# birth_month
# 12    27
# 6     18
# 3     14
# 8     14
# 9     14
# 7     13
# 11    12
# 2     12
# 4     11
# 10    10
# 1     10
# 5      8
# Name: count, dtype: int64
# ------------------
# 49
# birth_weekday
# 1    30
# 3    28
# 5    27
# 4    22
# 2    21
# 6    21
# 0    14
# Name: count, dtype: int64
# ------------------
# 44

# %%
sns.heatmap(df[numerical_data].drop(["date_sale","price","cumulative_price","id","birth_date"],axis=1).corr())
# Out:
# <Axes: >

# %%
features = df[numerical_data].drop(["date_sale","price","id","birth_date"],axis=1)
target = df["price"]

# %%
features.columns
# Out:
# Index(['index', 'deal_satisfaction', 'building', 'property', 'area',
#        'sale_month', 'sale_year', 'sale_weekday', 'birth_month', 'birth_year',
#        'birth_weekday', 'mortgage_df', 'cumulative_price', 'Age'],
#       dtype='object')

# %%
column = df[numerical_data].drop(["date_sale","price","id","cumulative_price","birth_date"],axis=1).columns

# %%
# def outlier_handling(col):
#     q1 = df[col].quantile(.25)
#     q3 = df[col].quantile(.75)
#     iqr = q3-q1
#     low = q1 - 1.5*iqr
#     high = q3+1.5*iqr
#     return df[(df[col]<high)&(df[col]>low)]
# df_new = outlier_handling("area")
# plt.subplot(1,2,1)
# df["area"].plot.box()
# plt.ylabel("Boxplot of area before Iqr outlier removal")
# plt.subplot(1,2,2)
# df_new["area"].plot.box()
# plt.ylabel("Boxplot of area after Iqr outlier removal")
# plt.tight_layout()
# plt.show()

# %%
1from sklearn.model_selection import train_test_split
X_train_stat,X_test_stat,y_train_stat,y_test_stat =  train_test_split(features,target,test_size=.2,shuffle=True,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_stat = scaler.fit_transform(X_train_stat)
X_test_stat = scaler.transform(X_test_stat)

# %%
import statsmodels.api as sm
statmodel = sm.OLS(y_train_stat,X_train_stat).fit()
statmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.957
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                              202.7
# Date:                Sun, 04 Feb 2024   Prob (F-statistic):                    1.14e-73
# Time:                        20:45:34   Log-Likelihood:                         -1611.2
# No. Observations:                 130   AIC:                                      3248.
# Df Residuals:                     117   BIC:                                      3286.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1         -7.527e+05   3.57e+05     -2.107      0.037   -1.46e+06   -4.51e+04
# x2         -1.259e+04   5707.548     -2.206      0.029   -2.39e+04   -1285.456
# x3          7665.2761   8801.191      0.871      0.386   -9765.021    2.51e+04
# x4          3.046e+04   6102.473      4.992      0.000    1.84e+04    4.25e+04
# x5          7.851e+04   6199.641     12.663      0.000    6.62e+04    9.08e+04
# x6         -1.228e+04   6289.856     -1.952      0.053   -2.47e+04     181.180
# x7          8.777e+18   1.75e+17     50.027      0.000    8.43e+18    9.12e+18
# x8          4988.9002   5823.571      0.857      0.393   -6544.378    1.65e+04
# x9          2377.3700   5678.151      0.419      0.676   -8867.911    1.36e+04
# x10        -9.834e+19   1.97e+18    -50.027      0.000   -1.02e+20   -9.44e+19
# x11        -2.214e+04   5666.806     -3.906      0.000   -3.34e+04   -1.09e+04
# x12        -5834.6334   5616.329     -1.039      0.301    -1.7e+04    5288.212
# x13         7.498e+05   3.57e+05      2.100      0.038    4.26e+04    1.46e+06
# x14        -9.899e+19   1.98e+18    -50.027      0.000   -1.03e+20   -9.51e+19
# ==============================================================================
# Omnibus:                        1.895   Durbin-Watson:                   2.335
# Prob(Omnibus):                  0.388   Jarque-Bera (JB):                1.594
# Skew:                          -0.123   Prob(JB):                        0.451
# Kurtosis:                       2.517   Cond. No.                     7.94e+14
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 4.85e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
summary = statmodel.summary()
p_value =summary.tables[1]
p_value = pd.DataFrame(p_value,columns=pd.DataFrame(p_value).iloc[0,:]).iloc[1:,4:]
p_value["Features"] = column.tolist()
p_value = p_value.iloc[:,[0,-1]]
p_value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[390], line 4
#       2 p_value =summary.tables[1]
#       3 p_value = pd.DataFrame(p_value,columns=pd.DataFrame(p_value).iloc[0,:]).iloc[1:,4:]
# ----> 4 p_value["Features"] = column.tolist()
#       5 p_value = p_value.iloc[:,[0,-1]]
#       6 p_value
#
# File ~/miniconda3/envs/projects/lib/python3.11/site-packages/pandas/core/frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~/miniconda3/envs/projects/lib/python3.11/site-packages/pandas/core/frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
#    4295     Add series to DataFrame in specified column.
#    4296
#    (...)
#    4301     ensure homogeneity.
#    4302     """
# -> 4303     value, refs = self._sanitize_column(value)
#    4305     if (
#    4306         key in self.columns
#    4307         and value.ndim == 1
#    4308         and not isinstance(value.dtype, ExtensionDtype)
#    4309     ):
#    4310         # broadcast across multiple columns if necessary
#    4311         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniconda3/envs/projects/lib/python3.11/site-packages/pandas/core/frame.py:5042, in DataFrame._sanitize_column(self, value)
#    5039     return _reindex_for_setitem(value, self.index)
#    5041 if is_list_like(value):
# -> 5042     com.require_length_match(value, self.index)
#    5043 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~/miniconda3/envs/projects/lib/python3.11/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (13) does not match length of index (14)

# %%
def EvaluationMatrix(y_test,y_pred):
    print("R2:",r2_score(y_pred,y_test))
    print("MSE:",mean_squared_error(y_pred,y_test))
EvaluationMatrix(y_test_stat,statmodel.predict(X_test_stat))
# Out:
# R2: -13.141860542629216
# MSE: 73606695009.13387

# %%
result = pd.DataFrame([y_test_stat,statmodel.predict(X_test_stat)],index=["Actual","Predicted"]).T
result.head()
# Out:
#         Actual     Predicted
# 22   290031.26 -28778.637423
# 93   293876.27           NaN
# 169  372001.70           NaN
# 152  263790.81           NaN
# 3    223917.34 -30508.735108

# %% [markdown]
# ### Machine learning Apporach

# %%
X = df.drop(["entity","country","date_sale","id","birth_date","name","surname","price","status","sex","state","purpose","mortgage","source","building","type","sale_year"],axis=1)
y = df["price"]

# %%
for col in X.columns:
    if df[col].nunique() <12:
        print(df[col].value_counts())
    else:
        print(df[col].nunique())
# Out:
# 163
# deal_satisfaction
# 5    51
# 4    38
# 3    33
# 2    24
# 1    17
# Name: count, dtype: int64
# 57
# 70
# 12
# sale_weekday
# 3    41
# 0    24
# 1    22
# 4    20
# 6    20
# 2    18
# 5    18
# Name: count, dtype: int64
# 12
# 49
# birth_weekday
# 1    30
# 3    28
# 5    27
# 4    22
# 2    21
# 6    21
# 0    14
# Name: count, dtype: int64
# mortgage_df
# 0    102
# 1     61
# Name: count, dtype: int64
# 163
# 44

# %%
X.head()
# Out:
#    deal_satisfaction  property     area  sale_month  sale_weekday  \
# 0                  4        51  1608.84           3             3
# 1                  1        45   756.21          10             4
# 2                  4        36  1127.76          10             0
# 3                  5        10   794.52          11             3
# 4                  5        11   794.52          11             3
#
#    birth_month  birth_year  birth_weekday  Age
# 0            5          31              5   39
# 1           11          25              0   42
# 2            4          23              1   48
# 3           11          23              2   48
# 4           11          23              2   48

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =  train_test_split(X,y,test_size=.2,shuffle=True,random_state=2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
pipe = Pipeline([("scaler",StandardScaler()),("model",LinearRegression())])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
from sklearn.metrics import r2_score,mean_squared_error
def EvaluationMatrix(y_test,y_pred):
    print("R2:",r2_score(y_pred,y_test))
    print("MSE:",mean_squared_error(y_pred,y_test))
EvaluationMatrix(y_test,y_pred)
# Out:
# R2: 0.87814773215334
# MSE: 637463372.0155257

# %%
from sklearn.ensemble import RandomForestRegressor
pipe = Pipeline([("scaler",StandardScaler()),("model",RandomForestRegressor(n_estimators=200))])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
from sklearn.metrics import r2_score,mean_squared_error
def EvaluationMatrix(y_test,y_pred):
    print("R2:",r2_score(y_pred,y_test))
    print("MSE:",mean_squared_error(y_pred,y_test))
EvaluationMatrix(y_test,y_pred)
# Out:
# R2: 0.8782732087940333
# MSE: 626150196.7036095

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = RandomForestRegressor(n_estimators=200,random_state=0)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=0)

# %%
model.score(X_test,y_test)
# Out:
# 0.8925118547614058

# %%
y_pred = model.predict(X_test)
EvaluationMatrix(y_test,y_pred)
# Out:
# R2: 0.8757770020802191
# MSE: 618863624.4026654

# %% [markdown]
# ### Hyperparameter tuning
#     Manually tune the parameters
#     use gridsearchcv

# %%
from sklearn.model_selection import GridSearchCV
### Manual method
lr_model = LinearRegression()
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(X_test,y_test)
# Out:
# 0.8892813330535869

# %%
y_pred_lr = lr_model.predict(X_test)
EvaluationMatrix(y_pred_lr,y_test)
# Out:
# R2: 0.8892813330535869
# MSE: 637463372.0155257

# %%
lr_model.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### GridSearchCv
params = {'n_jobs': [1,-1,None],'positive': [True,False],'copy_X': [True,False], 'fit_intercept': [False,True]}
grid = GridSearchCV(lr_model,params,cv=5,scoring='r2')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [False, True],
#                          'n_jobs': [1, -1, None], 'positive': [True, False]},
#              scoring='r2')

# %%
grid.best_score_
# Out:
# 0.8482450872763228

# %%
grid.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'positive': True}

# %%
EvaluationMatrix(y_test,grid.predict(X_test))
# Out:
# R2: 0.8762142512623738
# MSE: 646266292.6466775

# %%
### Use ridge or lasso models
from sklearn.linear_model import Ridge,Lasso
lasso = Lasso(max_iter=100,alpha = .001,positive=True,random_state=0,warm_start=True,precompute=True,selection="random")
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, max_iter=100, positive=True, precompute=True, random_state=0,
#       selection='random', warm_start=True)

# %%
y_pred_lasso = lasso.predict(X_test)
EvaluationMatrix(y_test,y_pred_lasso)
# Out:
# R2: 0.87619694285168
# MSE: 646843852.8231554

# %%
lasso.get_params()
# Out:
# {'alpha': 0.001,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 100,
#  'positive': True,
#  'precompute': True,
#  'random_state': 0,
#  'selection': 'random',
#  'tol': 0.0001,
#  'warm_start': True}

# %%
ridge = Ridge(max_iter=10,alpha = .001,positive=True,solver='lbfgs',random_state=0)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.001, max_iter=10, positive=True, random_state=0, solver='lbfgs')

# %%
y_pred_ridge = ridge.predict(X_test)
EvaluationMatrix(y_test,y_pred_ridge)
# Out:
# R2: 0.8763244051086428
# MSE: 645400648.3216331

# %%
y_pred_lasso = lasso.predict(X_test)
y_pred_lasso
# Out:
# array([332084.2233967 , 277720.29456448, 335093.36901044, 239372.6018758 ,
#        237673.51955019, 218322.48806463, 173669.46918039, 174341.08381999,
#        274559.2643298 , 338068.00534704, 274413.67900034, 238546.70261599,
#        210606.07483646, 202452.14936567, 415214.22826246, 332771.43970181,
#        243214.44451412, 247329.59704371, 244635.56678701, 470110.8479876 ,
#        242468.57831973, 324776.22628876, 242616.28254449, 243177.70179605,
#        238479.32007052, 270902.71557533, 275059.19293514, 242833.96879552,
#        238716.41886853, 205242.91784924, 335829.01642813, 476500.96309641,
#        226549.06612309])

# %%
X.columns
# Out:
# Index(['deal_satisfaction', 'property', 'area', 'sale_month', 'sale_weekday',
#        'birth_month', 'birth_year', 'birth_weekday', 'Age'],
#       dtype='object')

# %%
y_pred_lasso = lasso.predict(X_test)
predicted = pd.DataFrame(y_pred_lasso.tolist(),columns=["Predicted"])
predicted["Actual"] = y_test.tolist()
predicted.head()
# Out:
#        Predicted     Actual
# 0  332084.223397  290031.26
# 1  277720.294564  293876.27
# 2  335093.369010  372001.70
# 3  239372.601876  263790.81
# 4  237673.519550  223917.34

# %%
y_pred_lr = lr_model.predict(X_test)
predicted_lr = pd.DataFrame(y_pred_lr.tolist(),columns=["Predicted"])
predicted_lr["Actual"] = y_test.tolist()
predicted_lr.head()
# Out:
#        Predicted     Actual
# 0  330054.827414  290031.26
# 1  278493.292567  293876.27
# 2  332693.688486  372001.70
# 3  239057.598795  263790.81
# 4  235066.698709  223917.34

# %%
y_pred_lr = pipe.predict(X_test)
predicted_lr = pd.DataFrame(y_pred_lr.tolist(),columns=["Predicted"])
predicted_lr["Actual"] = y_test.tolist()
predicted_lr.head()
# Out:
#       Predicted     Actual
# 0  151353.80735  290031.26
# 1  151353.80735  293876.27
# 2  151402.38745  372001.70
# 3  151353.80735  263790.81
# 4  151402.38745  223917.34

# %%
y_pred_lr = model.predict(X_test)
predicted_lr = pd.DataFrame(y_pred_lr.tolist(),columns=["Predicted"])
predicted_lr["Actual"] = y_test.tolist()
predicted_lr.head()
# Out:
#       Predicted     Actual
# 0  317384.52945  290031.26
# 1  292635.61890  293876.27
# 2  313345.03835  372001.70
# 3  228477.25925  263790.81
# 4  211709.13600  223917.34

# %%
y_pred_lr = ridge.predict(X_test)
y_pred_lr = y_pred_lr*1000
predicted_lr = pd.DataFrame(y_pred_lr.tolist(),columns=["Predicted"])
predicted_lr["Actual"] = y_test.tolist()
predicted_lr.head()
# Out:
#       Predicted     Actual
# 0  3.313318e+08  290031.26
# 1  2.788630e+08  293876.27
# 2  3.343311e+08  372001.70
# 3  2.394561e+08  263790.81
# 4  2.368112e+08  223917.34

# %% [markdown]
# ### Conclusion:
#      # Based on the Model Performance rf Model performance gradually goood
#      # mean-squared-error is low compare to others model performance
#      # so further deployment ridge model will use and also check feature importances
#      # try xgboost/ada boost

# %%
# import xgboost as xgb

# %%
# param_grid = {
#     'learning_rate': [0.1, 0.01, 0.001],
#     'max_depth': [3, 5, 7],
#     'n_estimators': [100, 200, 300]
# }

# %%
# from xgboost import XGBRegressor
# xgboost = XGBRegressor(n_estimators=20)
# xgboost.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=20, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
# y_pred_xgboost = xgboost.predict(X_test)
# EvaluationMatrix(y_test,y_pred_xgboost)
# Out:
# R2: 0.8503130039487383
# MSE: 795077303.6645312

# %%
# grid_search = GridSearchCV(estimator=xgboost, param_grid=param_grid, scoring='neg_mean_squared_error', cv=3)
# grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=20,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid={'learning_rate': [0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
# grid_search.best_score_
# Out:
# -1503664780.02587

# %%
# grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}

# %%
# EvaluationMatrix(y_test,grid_search.predict(X_test))
# Out:
# R2: 0.8523876705528867
# MSE: 739845365.4348266

# %%
# predicted = pd.DataFrame([y_pred_xgboost],index=["Predicted"]).T
# predicted["Actual"] = y_test.tolist()
# predicted

# %%
features_imp = pd.DataFrame([X.columns,model.feature_importances_]).T
features_imp.columns = ["features","importance level"]
features_imp
# Out:
#             features importance level
# 0  deal_satisfaction         0.007976
# 1           property         0.014463
# 2               area         0.910083
# 3         sale_month         0.007269
# 4       sale_weekday          0.00764
# 5        birth_month         0.009402
# 6         birth_year         0.017414
# 7      birth_weekday         0.007451
# 8                Age         0.018302

# %%
### Feature importance

# %%
features_imp.set_index("features").plot.bar()
# Out:
# <Axes: xlabel='features'>

# %%
import pickle
with open("RealERstateAnalysisModel.pkl","wb") as file:
    pickle.dump(model,file)

# %%
model
# Out:
# RandomForestRegressor(n_estimators=200, random_state=0)

# %%
X.nunique().index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 X.nunique().index
#
# NameError: name 'X' is not defined

# %% [markdown]
# ### Conclusion :
#      # Data Science:
#         Best model is RandomForest . Store in Pickle. Use for futher Deployment
#
#     # Data Analysis:
#         Data interpretation below.  if u need will create dashboard

# %% [markdown]
# ### Deployment :
#      Creating Api and website

# %% [markdown]
# ** Flask used for the deployment portion . Flask is micro-framework used for create website **

# %% [markdown]
# *** Mlops may be used***

# %% [markdown]
# ### Data Interpretation
#     Based on the data analysis, what can you conclude about the customer profile, as well as the building characteristics?
#
#     * Which customer age bracket has the most buyers potential?
#        based on the histogram 30-40 has the most buyers potential
#
#     * Which Factor more important to predict price?
#         area - most important factor
#
#     * What is the highest priced building?
#         Apartment - 2 building higher price
#
#     *  What is the most sought after building?
#         area is the most sought after building

# %% [markdown]
# ### From DataScience And Machine Learning:
#
#     Datascience is the advanced analytical. predicting future or foresight`

# %% [markdown]
#     Machine learning is part of artificial intelligence. using artificial intelligence to predict foresight(forecast)

# %% [markdown]
#     Webscraping and api data retrival used for data collection
